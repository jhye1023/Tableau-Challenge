# %%
import glob
import pandas as pd

# %%
ridership = pd.concat([pd.read_csv(f) for f in glob.glob('Data/*.csv')], ignore_index = True, sort=False )
# clean_data_trip = pd.concat([pd.read_csv(f) for f in glob.glob('raw_data/CitiBikeTripHistories/*.csv')], ignore_index = True)

# %%
ridership.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           122  2020-06-01 00:02:21.7500  2020-06-01 00:04:24.3250
# 1          1282  2020-06-01 00:12:27.1090  2020-06-01 00:33:50.0540
# 2           186  2020-06-01 01:19:59.2090  2020-06-01 01:23:05.8930
# 3           131  2020-06-01 01:26:42.2050  2020-06-01 01:28:53.8040
# 4           266  2020-06-01 01:27:33.7090  2020-06-01 01:32:00.1890
#
#    start station id          start station name  start station latitude  \
# 0              3792  Columbus Dr at Exchange Pl               40.716870
# 1              3198            Heights Elevator               40.748716
# 2              3275              Columbus Drive               40.718355
# 3              3267                Morris Canal               40.712419
# 4              3639                  Harborside               40.719252
#
#    start station longitude  end station id  end station name  \
# ...

# %%
ridership.count()
# Out:
# tripduration               372446
# starttime                  372446
# stoptime                   372446
# start station id           372446
# start station name         372446
# start station latitude     372446
# start station longitude    372446
# end station id             372446
# end station name           372446
# end station latitude       372446
# end station longitude      372446
# bikeid                     372446
# usertype                   372446
# birth year                 372446
# gender                     372446
# dtype: int64

# %%
Gender = {0: 'unknown', 1 : 'male', 2 : 'female'}
ridership.gender = [Gender[item] for item in ridership.gender]
ridership.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           122  2020-06-01 00:02:21.7500  2020-06-01 00:04:24.3250
# 1          1282  2020-06-01 00:12:27.1090  2020-06-01 00:33:50.0540
# 2           186  2020-06-01 01:19:59.2090  2020-06-01 01:23:05.8930
# 3           131  2020-06-01 01:26:42.2050  2020-06-01 01:28:53.8040
# 4           266  2020-06-01 01:27:33.7090  2020-06-01 01:32:00.1890
#
#    start station id          start station name  start station latitude  \
# 0              3792  Columbus Dr at Exchange Pl               40.716870
# 1              3198            Heights Elevator               40.748716
# 2              3275              Columbus Drive               40.718355
# 3              3267                Morris Canal               40.712419
# 4              3639                  Harborside               40.719252
#
#    start station longitude  end station id  end station name  \
# ...

# %%
ridership.to_csv("Final_Data/data_2019-07_2020-06.csv")
